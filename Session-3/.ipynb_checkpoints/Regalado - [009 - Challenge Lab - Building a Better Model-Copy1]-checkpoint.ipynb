# %% [markdown]
# ### Challenge Lab
#
# **Instructions**: Build a model using a Built-in Algorithm that performs better than the model we have trained in Lab 008. Use the Automated Model Tuning capability of SageMaker to help you find the best model.

# %%
import pandas as pd
import numpy as np

# %%
np.set_printoptions(suppress=True, precision=2)
pd.set_option('display.float_format', lambda x: '%.10f' % x)

# %%
df = pd.read_csv("files/003.csv")
df.head()
# Out:
#    target  a  b  c   d   e  f  g  h
# 0  151400  2  2  3   7  37  0  3  0
# 1  286000  4  4  6  16  64  0  6  0
# 2  172200  2  2  4  24  16  2  3  0
# 3  141400  4  4  4   0  32  1  4  0
# 4  100800  3  3  4   8   8  0  4  0

# %%
from sklearn.model_selection import train_test_split

# X = df.drop('target', axis=1)
X = df.drop(['target'], axis=1)

X_train, X_val, y_train, y_val = train_test_split(X.values, df['target'].values, test_size=0.20, random_state=0)

# %%
X_train
# Out:
# array([[  0,   0,   0, ...,   0,   0,   0],
#        [ 10,  10,  10, ...,   0,  10,   0],
#        [ 24,  24,  24, ...,   6,  24,   0],
#        ...,
#        [ 50,  50,  10, ...,   0,   0,   0],
#        [ 60,  20,  10, ...,   0,   0,  60],
#        [  0,   0,   0, ...,   0,   0, 120]])

# %%
y_train
# Out:
# array([   9600,  634000,  848400,  612800,  456000,  712800,   28800,
#         960000,   84800,  148800,  720000,  480000, 1570800, 1047200,
#         749600,  470400,  169600,  302800,  344400, 2580000,   95200,
#        3084000,  433600,  630800, 1300800,  919200,  201600,  143000,
#        2280000,  286000,   92800,  393000,   46400,  448000,  216800,
#         856000,  823200, 1716000, 1646400, 1128800,  313600,  100800,
#         480000,  424200,  666000,  749600,  356400,  224000, 2736000,
#        2508000,  254400,  572000,  868800, 1028000,  561600, 1720000,
#         219600,  141400,  429000,  380000,  572000,  146400, 1268000,
#         516600,  680000, 1225600,  606000,  548800,  418000, 1300800,
#         168000, 1208000,  190400, 1902000, 1268000,  172200,  313600,
#         860000,  888000,   84000,  564400, 1208000,  454200,  912000,
#         120000,  786000, 1360000,  842400,  302400,  786000, 1212000,
#         109800, 2568000,  548800,  240000, 3624000,  282800,  680000,
#         480000,  240000,  500000, 2606400,   36600,   60400,  156800,
#         403200,  523600,  286000,  151400,  306400,   74400, 2040000,
#        1303200,  606000,  836000, 1020000,  181200,   57600,  374800,
#         297600,  237600,  909000,   30200,   69600,  169600, 1440000,
#          28800, 1693200,  672000,  115200,  285600,   19200,  446400,
#         856000,  500000, 1818000,  280800, 1261600, 1892400,  434400,
#         946200,  428000,   57600,   56000,   38400,  785400,  286000,
#        1290000,  860000, 2536000, 2056000,  190400,   90600,  339200,
#         274400,  444000,  720000,  760000,  605600, 2358000,  750000,
#          19200,   28000, 1672000,   73200, 3386400,   56000,  433600,
#        1332000,  344400,  612800,  223200, 1572000, 1000000,  508800,
#         282800,  565600,  523600,   73200,  912000,  302800, 4112000,
#        2248800,   23200, 1140000,  139200, 1737600, 1179000,  604800,
#         867200, 1440000,   46400, 2056000, 1500000,  360000, 1254000,
#         604000, 1144000, 1124400, 1684800, 2257600,  940800, 1128800,
#         908400,  430000, 1368000,  315400, 1123200, 1816800,  222000,
#        1033200,  120800,  112000,  480000,  605600,  475200])

# %%
import io
import sagemaker
import sagemaker.amazon.common as smac

sesh = sagemaker.Session()
bucket = sesh.default_bucket()

# convert the training data to a recordIO-wrapped protobuf format used by the Amazon SageMaker algorithms

# init memory buffer in RAM where data will be written
buf = io.BytesIO()

# write train data (numpy array) into a dense tensor 
# smac.write_numpy_to_dense_tensor(buf, X_train.astype("float32"), y_train.astype("float32"))
smac.write_numpy_to_dense_tensor(buf, X_train.reshape(-1, 8).astype("float32"), y_train.astype("float32"))

# sets the file's current position at the offset (0)
# i.e. set the reference point to the beginning of the memory buffer
buf.seek(0)
# Out:
# 0

# %%
import os
import boto3

# upload training data to s3
key = "009-train-data"
prefix = "sagemaker/009"

boto3.resource("s3").Bucket(bucket).Object(os.path.join(prefix, "train", key)).upload_fileobj(buf)
s3_train_data = f"s3://{bucket}/{prefix}/train/{key}"

print(f"uploaded training data location: {s3_train_data}")
# Out:
# uploaded training data location: s3://sagemaker-us-east-1-305262579855/sagemaker/009/train/009-train-data

# %%
# convert the validation data to a recordIO-wrapped protobuf format used by the Amazon SageMaker algorithms 

buf = io.BytesIO()
smac.write_numpy_to_dense_tensor(buf, X_val.astype("float32").reshape(-1, 8), y_val.astype("float32"))
buf.seek(0)
# Out:
# 0

# %%
# upload validation data to s3

key = "009-valid-data"
prefix = "sagemaker/009"

boto3.resource("s3").Bucket(bucket).Object(os.path.join(prefix, "valid", key)).upload_fileobj(buf)
s3_valid_data = f"s3://{bucket}/{prefix}/valid/{key}"

print(f"uploaded validation data location: {s3_train_data}")
# Out:
# uploaded validation data location: s3://sagemaker-us-east-1-305262579855/sagemaker/009/train/009-train-data

# %%
import boto3
import sagemaker
from sagemaker import tuner
from sagemaker import get_execution_role

role = get_execution_role()
sesh = sagemaker.Session()
bucket = sesh.default_bucket()
region = boto3.Session().region_name    
client = boto3.Session().client('sagemaker')

# %%
from sagemaker.image_uris import retrieve

container = retrieve('linear-learner', region, version="1")
container
# Out:
# '382416733822.dkr.ecr.us-east-1.amazonaws.com/linear-learner:1'

# %%
# !pip install 'sagemaker[local]' --upgrade
# Out:
# Requirement already satisfied: sagemaker[local] in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (2.42.1)
# Requirement already satisfied: attrs in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker[local]) (20.3.0)
# Requirement already satisfied: google-pasta in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker[local]) (0.2.0)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker[local]) (20.9)
# Requirement already satisfied: pathos in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker[local]) (0.2.7)
# Requirement already satisfied: importlib-metadata>=1.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker[local]) (3.7.0)
# Requirement already satisfied: numpy>=1.9.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker[local]) (1.19.5)
# Requirement already satisfied: protobuf>=3.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker[local]) (3.15.2)
# Requirement already satisfied: protobuf3-to-dict>=0.1.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker[local]) (0.1.5)
# Requirement already satisfied: boto3>=1.16.32 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker[local]) (1.17.83)
# Requirement already satisfied: smdebug-rulesconfig==1.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker[local]) (1.0.1)
# Requirement already satisfied: pandas in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker[local]) (1.1.5)
# Requirement already satisfied: docker-compose>=1.25.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker[local]) (1.29.2)
# Requirement already satisfied: urllib3!=1.25,!=1.25.1,>=1.21.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker[local]) (1.26.5)
# Requirement already satisfied: PyYAML<6,>=5.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker[local]) (5.4.1)
# Requirement already satisfied: s3transfer<0.5.0,>=0.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3>=1.16.32->sagemaker[local]) (0.4.2)
# Requirement already satisfied: botocore<1.21.0,>=1.20.83 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3>=1.16.32->sagemaker[local]) (1.20.83)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3>=1.16.32->sagemaker[local]) (0.10.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from botocore<1.21.0,>=1.20.83->boto3>=1.16.32->sagemaker[local]) (2.8.1)
# Requirement already satisfied: cached-property<2,>=1.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from docker-compose>=1.25.2->sagemaker[local]) (1.5.1)
# Requirement already satisfied: docker[ssh]>=5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from docker-compose>=1.25.2->sagemaker[local]) (5.0.0)
# Requirement already satisfied: python-dotenv<1,>=0.13.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from docker-compose>=1.25.2->sagemaker[local]) (0.17.1)
# Requirement already satisfied: requests<3,>=2.20.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from docker-compose>=1.25.2->sagemaker[local]) (2.25.1)
# Requirement already satisfied: jsonschema<4,>=2.5.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from docker-compose>=1.25.2->sagemaker[local]) (3.2.0)
# Requirement already satisfied: texttable<2,>=0.9.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from docker-compose>=1.25.2->sagemaker[local]) (1.6.3)
# Requirement already satisfied: dockerpty<1,>=0.4.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from docker-compose>=1.25.2->sagemaker[local]) (0.4.1)
# Requirement already satisfied: websocket-client<1,>=0.32.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from docker-compose>=1.25.2->sagemaker[local]) (0.59.0)
# Requirement already satisfied: distro<2,>=1.5.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from docker-compose>=1.25.2->sagemaker[local]) (1.5.0)
# Requirement already satisfied: docopt<1,>=0.6.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from docker-compose>=1.25.2->sagemaker[local]) (0.6.2)
# Requirement already satisfied: paramiko>=2.4.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from docker[ssh]>=5->docker-compose>=1.25.2->sagemaker[local]) (2.7.2)
# Requirement already satisfied: six>=1.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from dockerpty<1,>=0.4.1->docker-compose>=1.25.2->sagemaker[local]) (1.15.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from importlib-metadata>=1.4.0->sagemaker[local]) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from importlib-metadata>=1.4.0->sagemaker[local]) (3.4.0)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from jsonschema<4,>=2.5.1->docker-compose>=1.25.2->sagemaker[local]) (49.6.0.post20210108)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from jsonschema<4,>=2.5.1->docker-compose>=1.25.2->sagemaker[local]) (0.17.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from packaging>=20.0->sagemaker[local]) (2.4.7)
# Requirement already satisfied: cryptography>=2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from paramiko>=2.4.2->docker[ssh]>=5->docker-compose>=1.25.2->sagemaker[local]) (3.4.4)
# Requirement already satisfied: bcrypt>=3.1.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from paramiko>=2.4.2->docker[ssh]>=5->docker-compose>=1.25.2->sagemaker[local]) (3.2.0)
# Requirement already satisfied: pynacl>=1.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from paramiko>=2.4.2->docker[ssh]>=5->docker-compose>=1.25.2->sagemaker[local]) (1.4.0)
# Requirement already satisfied: cffi>=1.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from bcrypt>=3.1.3->paramiko>=2.4.2->docker[ssh]>=5->docker-compose>=1.25.2->sagemaker[local]) (1.14.5)
# Requirement already satisfied: pycparser in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from cffi>=1.1->bcrypt>=3.1.3->paramiko>=2.4.2->docker[ssh]>=5->docker-compose>=1.25.2->sagemaker[local]) (2.20)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3,>=2.20.0->docker-compose>=1.25.2->sagemaker[local]) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3,>=2.20.0->docker-compose>=1.25.2->sagemaker[local]) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3,>=2.20.0->docker-compose>=1.25.2->sagemaker[local]) (2.10)
# Requirement already satisfied: pytz>=2017.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pandas->sagemaker[local]) (2021.1)
# Requirement already satisfied: ppft>=1.6.6.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pathos->sagemaker[local]) (1.6.6.3)
# Requirement already satisfied: multiprocess>=0.70.11 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pathos->sagemaker[local]) (0.70.11.1)
# Requirement already satisfied: pox>=0.2.9 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pathos->sagemaker[local]) (0.2.9)
# Requirement already satisfied: dill>=0.3.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pathos->sagemaker[local]) (0.3.3)

# %%
# !sudo service docker restart
# Out:
# Stopping docker: [  OK  ]
# Starting docker:	.[  OK  ]

# %%
estimator = sagemaker.estimator.Estimator(
    container,
    role,
    instance_count=1,
    instance_type="ml.m4.xlarge",
    sagemaker_session=sesh
)

# %%
estimator.set_hyperparameters(
    predictor_type='regressor',
    normalize_data=True,
    optimizer="adam",
)

# %%
hyperparameter_ranges = {
    'learning_rate': tuner.ContinuousParameter(1e-5, 1),
    'mini_batch_size': tuner.IntegerParameter(2, 10),
    'l1': tuner.ContinuousParameter(1e-7, 1),
    'use_bias': tuner.CategoricalParameter([True, False]),
    'wd': tuner.ContinuousParameter(1e-7, 1)
}

# %%
objective_metric_name = 'validation:objective_loss'

# %%
hyperparameter_tuner = tuner.HyperparameterTuner(
    estimator,
    objective_metric_name,
    hyperparameter_ranges, 
    objective_type='Minimize',
    max_jobs=12,
    max_parallel_jobs=3
)

# %%
hyperparameter_tuner.fit(
    {'train': s3_train_data, 'validation': s3_valid_data},
    include_cls_metadata=False,
    wait=False
)

job_name = hyperparameter_tuner.latest_tuning_job.job_name

response = client.describe_hyper_parameter_tuning_job(
    HyperParameterTuningJobName=job_name
)

response['HyperParameterTuningJobStatus']
# Out:
# 'InProgress'

# %%
from pprint import pprint

pprint(response)
# Out:
# {'CreationTime': datetime.datetime(2021, 6, 5, 8, 30, 40, 617000, tzinfo=tzlocal()),
#  'HyperParameterTuningJobArn': 'arn:aws:sagemaker:us-east-1:305262579855:hyper-parameter-tuning-job/linear-learner-210605-0830',
#  'HyperParameterTuningJobConfig': {'HyperParameterTuningJobObjective': {'MetricName': 'validation:objective_loss',
#                                                                         'Type': 'Minimize'},
#                                    'ParameterRanges': {'CategoricalParameterRanges': [{'Name': 'use_bias',
#                                                                                        'Values': ['True',
#                                                                                                   'False']}],
#                                                        'ContinuousParameterRanges': [{'MaxValue': '1',
#                                                                                       'MinValue': '1e-05',
#                                                                                       'Name': 'learning_rate',
#                                                                                       'ScalingType': 'Auto'},
#                                                                                      {'MaxValue': '1',
#                                                                                       'MinValue': '1e-07',
#                                                                                       'Name': 'l1',
#                                                                                       'ScalingType': 'Auto'},
#                                                                                      {'MaxValue': '1',
#                                                                                       'MinValue': '1e-07',
#                                                                                       'Name': 'wd',
#                                                                                       'ScalingType': 'Auto'}],
#                                                        'IntegerParameterRanges': [{'MaxValue': '10',
#                                                                                    'MinValue': '2',
#                                                                                    'Name': 'mini_batch_size',
#                                                                                    'ScalingType': 'Auto'}]},
#                                    'ResourceLimits': {'MaxNumberOfTrainingJobs': 12,
#                                                       'MaxParallelTrainingJobs': 3},
#                                    'Strategy': 'Bayesian',
#                                    'TrainingJobEarlyStoppingType': 'Off'},
#  'HyperParameterTuningJobName': 'linear-learner-210605-0830',
#  'HyperParameterTuningJobStatus': 'InProgress',
#  'LastModifiedTime': datetime.datetime(2021, 6, 5, 8, 30, 40, 617000, tzinfo=tzlocal()),
#  'ObjectiveStatusCounters': {'Failed': 0, 'Pending': 0, 'Succeeded': 0},
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '6797',
#                                       'content-type': 'application/x-amz-json-1.1',
#                                       'date': 'Sat, 05 Jun 2021 08:30:40 GMT',
#                                       'x-amzn-requestid': '4bf81c26-4de4-4789-8f52-d0c92f2aea53'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '4bf81c26-4de4-4789-8f52-d0c92f2aea53',
#                       'RetryAttempts': 0},
#  'TrainingJobDefinition': {'AlgorithmSpecification': {'MetricDefinitions': [{'Name': 'test:dcg',
#                                                                              'Regex': '#quality_metric: '
#                                                                                       'host=\\S+, '
#                                                                                       'test '
#                                                                                       'dcg '
#                                                                                       '<score>=(\\S+)'},
#                                                                             {'Name': 'train:progress',
#                                                                              'Regex': '#progress_metric: '
#                                                                                       'host=\\S+, '
#                                                                                       'completed '
#                                                                                       '(\\S+) '
#                                                                                       '%'},
#                                                                             {'Name': 'test:binary_f_beta',
#                                                                              'Regex': '#quality_metric: '
#                                                                                       'host=\\S+, '
#                                                                                       'test '
#                                                                                       'binary_f_\\S+ '
#                                                                                       '<score>=(\\S+)'},
#                                                                             {'Name': 'train:objective_loss',
#                                                                              'Regex': '#quality_metric: '
#                                                                                       'host=\\S+, '
#                                                                                       'epoch=\\S+, '
#                                                                                       'train '
#                                                                                       '\\S+_objective '
#                                                                                       '<loss>=(\\S+)'},
#                                                                             {'Name': 'validation:macro_precision',
#                                                                              'Regex': '#quality_metric: '
#                                                                                       'host=\\S+, '
#                                                                                       'validation '
#                                                                                       'macro_precision '
#                                                                                       '<score>=(\\S+)'},
#                                                                             {'Name': 'validation:dcg',
#                                                                              'Regex': '#quality_metric: '
#                                                                                       'host=\\S+, '
#                                                                                       'validation '
#                                                                                       'dcg '
#                                                                                       '<score>=(\\S+)'},
#                                                                             {'Name': 'test:mse',
#                                                                              'Regex': '#quality_metric: '
#                                                                                       'host=\\S+, '
#                                                                                       'test '
#                                                                                       'mse '
#                                                                                       '<loss>=(\\S+)'},
#                                                                             {'Name': 'validation:binary_f_beta',
#                                                                              'Regex': '#quality_metric: '
#                                                                                       'host=\\S+, '
#                                                                                       'validation '
#                                                                                       'binary_f_\\S+ '
#                                                                                       '<score>=(\\S+)'},
#                                                                             {'Name': 'validation:objective_loss',
#                                                                              'Regex': '#quality_metric: '
#                                                                                       'host=\\S+, '
#                                                                                       'epoch=\\S+, '
#                                                                                       'validation '
#                                                                                       '\\S+_objective '
#                                                                                       '<loss>=(\\S+)'},
#                                                                             {'Name': 'validation:objective_loss:final',
#                                                                              'Regex': '#quality_metric: '
#                                                                                       'host=\\S+, '
#                                                                                       'validation '
#                                                                                       '\\S+_objective '
#                                                                                       '<loss>=(\\S+)'},
#                                                                             {'Name': 'test:macro_recall',
#                                                                              'Regex': '#quality_metric: '
#                                                                                       'host=\\S+, '
#                                                                                       'test '
#                                                                                       'macro_recall '
#                                                                                       '<score>=(\\S+)'},
#                                                                             {'Name': 'test:absolute_loss',
#                                                                              'Regex': '#quality_metric: '
#                                                                                       'host=\\S+, '
#                                                                                       'test '
#                                                                                       'absolute_loss '
#                                                                                       '<loss>=(\\S+)'},
#                                                                             {'Name': 'train:recall',
#                                                                              'Regex': '#quality_metric: '
#                                                                                       'host=\\S+, '
#                                                                                       'train '
#                                                                                       'recall '
#                                                                                       '<score>=(\\S+)'},
#                                                                             {'Name': 'train:mse',
#                                                                              'Regex': '#quality_metric: '
#                                                                                       'host=\\S+, '
#                                                                                       'train '
#                                                                                       'mse '
#                                                                                       '<loss>=(\\S+)'},
#                                                                             {'Name': 'validation:roc_auc_score',
#                                                                              'Regex': '#quality_metric: '
#                                                                                       'host=\\S+, '
#                                                                                       'validation '
#                                                                                       'roc_auc_score '
#                                                                                       '<score>=(\\S+)'},
#                                                                             {'Name': 'train:precision',
#                                                                              'Regex': '#quality_metric: '
#                                                                                       'host=\\S+, '
#                                                                                       'train '
#                                                                                       'precision '
#                                                                                       '<score>=(\\S+)'},
#                                                                             {'Name': 'train:objective_loss:final',
#                                                                              'Regex': '#quality_metric: '
#                                                                                       'host=\\S+, '
#                                                                                       'train '
#                                                                                       '\\S+_objective '
#                                                                                       '<loss>=(\\S+)'},
#                                                                             {'Name': 'validation:recall',
#                                                                              'Regex': '#quality_metric: '
#                                                                                       'host=\\S+, '
#                                                                                       'validation '
#                                                                                       'recall '
#                                                                                       '<score>=(\\S+)'},
#                                                                             {'Name': 'test:multiclass_accuracy',
#                                                                              'Regex': '#quality_metric: '
#                                                                                       'host=\\S+, '
#                                                                                       'test '
#                                                                                       'multiclass_accuracy '
#                                                                                       '<score>=(\\S+)'},
#                                                                             {'Name': 'validation:precision',
#                                                                              'Regex': '#quality_metric: '
#                                                                                       'host=\\S+, '
#                                                                                       'validation '
#                                                                                       'precision '
#                                                                                       '<score>=(\\S+)'},
#                                                                             {'Name': 'validation:multiclass_accuracy',
#                                                                              'Regex': '#quality_metric: '
#                                                                                       'host=\\S+, '
#                                                                                       'validation '
#                                                                                       'multiclass_accuracy '
#                                                                                       '<score>=(\\S+)'},
#                                                                             {'Name': 'train:binary_f_beta',
#                                                                              'Regex': '#quality_metric: '
#                                                                                       'host=\\S+, '
#                                                                                       'train '
#                                                                                       'binary_f_\\S+ '
#                                                                                       '<score>=(\\S+)'},
#                                                                             {'Name': 'test:recall',
#                                                                              'Regex': '#quality_metric: '
#                                                                                       'host=\\S+, '
#                                                                                       'test '
#                                                                                       'recall '
#                                                                                       '<score>=(\\S+)'},
#                                                                             {'Name': 'test:macro_precision',
#                                                                              'Regex': '#quality_metric: '
#                                                                                       'host=\\S+, '
#                                                                                       'test '
#                                                                                       'macro_precision '
#                                                                                       '<score>=(\\S+)'},
#                                                                             {'Name': 'test:macro_f_beta',
#                                                                              'Regex': '#quality_metric: '
#                                                                                       'host=\\S+, '
#                                                                                       'test '
#                                                                                       'macro_f_\\S+ '
#                                                                                       '<score>=(\\S+)'},
#                                                                             {'Name': 'test:objective_loss',
#                                                                              'Regex': '#quality_metric: '
#                                                                                       'host=\\S+, '
#                                                                                       'test '
#                                                                                       '\\S+_objective '
#                                                                                       '<loss>=(\\S+)'},
#                                                                             {'Name': 'test:precision',
#                                                                              'Regex': '#quality_metric: '
#                                                                                       'host=\\S+, '
#                                                                                       'test '
#                                                                                       'precision '
#                                                                                       '<score>=(\\S+)'},
#                                                                             {'Name': 'validation:multiclass_top_k_accuracy',
#                                                                              'Regex': '#quality_metric: '
#                                                                                       'host=\\S+, '
#                                                                                       'validation '
#                                                                                       'multiclass_top_k_accuracy_\\S+ '
#                                                                                       '<score>=(\\S+)'},
#                                                                             {'Name': 'train:binary_classification_accuracy',
#                                                                              'Regex': '#quality_metric: '
#                                                                                       'host=\\S+, '
#                                                                                       'train '
#                                                                                       'binary_classification_accuracy '
#                                                                                       '<score>=(\\S+)'},
#                                                                             {'Name': 'validation:mse',
#                                                                              'Regex': '#quality_metric: '
#                                                                                       'host=\\S+, '
#                                                                                       'validation '
#                                                                                       'mse '
#                                                                                       '<loss>=(\\S+)'},
#                                                                             {'Name': 'test:multiclass_top_k_accuracy',
#                                                                              'Regex': '#quality_metric: '
#                                                                                       'host=\\S+, '
#                                                                                       'test '
#                                                                                       'multiclass_top_k_accuracy_\\S+ '
#                                                                                       '<score>=(\\S+)'},
#                                                                             {'Name': 'validation:binary_classification_accuracy',
#                                                                              'Regex': '#quality_metric: '
#                                                                                       'host=\\S+, '
#                                                                                       'validation '
#                                                                                       'binary_classification_accuracy '
#                                                                                       '<score>=(\\S+)'},
#                                                                             {'Name': 'train:absolute_loss',
#                                                                              'Regex': '#quality_metric: '
#                                                                                       'host=\\S+, '
#                                                                                       'train '
#                                                                                       'absolute_loss '
#                                                                                       '<loss>=(\\S+)'},
#                                                                             {'Name': 'validation:macro_recall',
#                                                                              'Regex': '#quality_metric: '
#                                                                                       'host=\\S+, '
#                                                                                       'validation '
#                                                                                       'macro_recall '
#                                                                                       '<score>=(\\S+)'},
#                                                                             {'Name': 'train:throughput',
#                                                                              'Regex': '#throughput_metric: '
#                                                                                       'host=\\S+, '
#                                                                                       'train '
#                                                                                       'throughput=(\\S+) '
#                                                                                       'records/second'},
#                                                                             {'Name': 'test:binary_classification_accuracy',
#                                                                              'Regex': '#quality_metric: '
#                                                                                       'host=\\S+, '
#                                                                                       'test '
#                                                                                       'binary_classification_accuracy '
#                                                                                       '<score>=(\\S+)'},
#                                                                             {'Name': 'validation:absolute_loss',
#                                                                              'Regex': '#quality_metric: '
#                                                                                       'host=\\S+, '
#                                                                                       'validation '
#                                                                                       'absolute_loss '
#                                                                                       '<loss>=(\\S+)'},
#                                                                             {'Name': 'validation:macro_f_beta',
#                                                                              'Regex': '#quality_metric: '
#                                                                                       'host=\\S+, '
#                                                                                       'validation '
#                                                                                       'macro_f_\\S+ '
#                                                                                       '<score>=(\\S+)'},
#                                                                             {'Name': 'test:roc_auc_score',
#                                                                              'Regex': '#quality_metric: '
#                                                                                       'host=\\S+, '
#                                                                                       'test '
#                                                                                       'roc_auc_score '
#                                                                                       '<score>=(\\S+)'},
#                                                                             {'Name': 'ObjectiveMetric',
#                                                                              'Regex': '#quality_metric: '
#                                                                                       'host=\\S+, '
#                                                                                       'epoch=\\S+, '
#                                                                                       'validation '
#                                                                                       '\\S+_objective '
#                                                                                       '<loss>=(\\S+)'}],
#                                                       'TrainingImage': '382416733822.dkr.ecr.us-east-1.amazonaws.com/linear-learner:1',
#                                                       'TrainingInputMode': 'File'},
#                            'EnableInterContainerTrafficEncryption': False,
#                            'EnableManagedSpotTraining': False,
#                            'EnableNetworkIsolation': False,
#                            'InputDataConfig': [{'ChannelName': 'train',
#                                                 'DataSource': {'S3DataSource': {'S3DataDistributionType': 'FullyReplicated',
#                                                                                 'S3DataType': 'S3Prefix',
#                                                                                 'S3Uri': 's3://sagemaker-us-east-1-305262579855/sagemaker/009/train/009-train-data'}}},
#                                                {'ChannelName': 'validation',
#                                                 'DataSource': {'S3DataSource': {'S3DataDistributionType': 'FullyReplicated',
#                                                                                 'S3DataType': 'S3Prefix',
#                                                                                 'S3Uri': 's3://sagemaker-us-east-1-305262579855/sagemaker/009/valid/009-valid-data'}}}],
#                            'OutputDataConfig': {'S3OutputPath': 's3://sagemaker-us-east-1-305262579855/'},
#                            'ResourceConfig': {'InstanceCount': 1,
#                                               'InstanceType': 'ml.m4.xlarge',
#                                               'VolumeSizeInGB': 30},
#                            'RoleArn': 'arn:aws:iam::305262579855:role/service-role/AmazonSageMaker-ExecutionRole-20210507T101941',
#                            'StaticHyperParameters': {'_tuning_objective_metric': 'validation:objective_loss',
#                                                      'normalize_data': 'True',
#                                                      'optimizer': 'adam',
#                                                      'predictor_type': 'regressor'},
#                            'StoppingCondition': {'MaxRuntimeInSeconds': 86400}},
#  'TrainingJobStatusCounters': {'Completed': 0,
#                                'InProgress': 0,
#                                'NonRetryableError': 0,
#                                'RetryableError': 0,
#                                'Stopped': 0}}

# %%
hyperparameter_tuner.__dict__
# Out:
# {'estimator': <sagemaker.estimator.Estimator at 0x7fc664be11d0>,
#  'objective_metric_name': 'validation:objective_loss',
#  '_hyperparameter_ranges': {'learning_rate': <sagemaker.parameter.ContinuousParameter at 0x7fc6627cf390>,
#   'mini_batch_size': <sagemaker.parameter.IntegerParameter at 0x7fc6627cf940>,
#   'l1': <sagemaker.parameter.ContinuousParameter at 0x7fc6627cf400>,
#   'use_bias': <sagemaker.parameter.CategoricalParameter at 0x7fc6627cfeb8>,
#   'wd': <sagemaker.parameter.ContinuousParameter at 0x7fc6627cf518>},
#  'metric_definitions': None,
#  'estimator_dict': None,
#  'objective_metric_name_dict': None,
#  '_hyperparameter_ranges_dict': None,
#  'metric_definitions_dict': None,
#  'static_hyperparameters_dict': None,
#  'strategy': 'Bayesian',
#  'objective_type': 'Minimize',
#  'max_jobs': 12,
#  'max_parallel_jobs': 3,
#  'tags': None,
#  'base_tuning_job_name': None,
#  '_current_job_name': 'linear-learner-210605-0830',
#  'latest_tuning_job': <sagemaker.tuner._TuningJob at 0x7fc664bd2080>,
#  'warm_start_config': None,
#  'early_stopping_type': 'Off',
#  'static_hyperparameters': {'predictor_type': 'regressor',
#   'normalize_data': 'True',
#   'optimizer': 'adam'}}

# %%
tuning_job_name = response['HyperParameterTuningJobName']
# %store tuning_job_name

tuning_job_name
# Out:
# Stored 'tuning_job_name' (str)
# 'linear-learner-210605-0830'

# %%
from time import sleep

while response['HyperParameterTuningJobStatus'] == 'InProgress':
    response = client.describe_hyper_parameter_tuning_job(
        HyperParameterTuningJobName=job_name
    )

    print(response['HyperParameterTuningJobStatus'])
    sleep(60)
# Out:
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# Completed

# %%
# %store -r tuning_job_name

from sagemaker import HyperparameterTuningJobAnalytics

def latest_df():
    analytics = HyperparameterTuningJobAnalytics(tuning_job_name)

    return analytics.dataframe()    

latest_df().sort_values('FinalObjectiveValue', ascending=True)
# Out:
#              l1  learning_rate  mini_batch_size use_bias           wd  \
# 0  0.0000117427   0.0492325764     9.0000000000     True 0.0000033638
# 5  0.0000001248   0.0020420037     8.0000000000    False 0.0000002638
# 4  0.0000001517   0.9189876876     2.0000000000    False 0.0958499963
# 8  0.0000378051   0.4094538476     2.0000000000    False 0.0000002363
# 7  0.0000004888   0.5141406114     4.0000000000    False 0.0042699848
# 6  0.0000006747   0.5141406114     4.0000000000    False 0.0030933305
# 11 0.0001943719   0.2732908696     6.0000000000    False 0.0015788296
# 9  0.1196055414   0.0004430244     2.0000000000     True 0.0000076043
# 10 0.2011335612   0.0004450943     7.0000000000     True 0.0005756771
# 3  0.0000003478   0.4511481848     5.0000000000    False 0.0000001560
# 2  0.0073757041   0.0000123997     2.0000000000    False 0.0000001164
# 1  0.0000001316   0.0000149010     3.0000000000    False 0.0000485952
#
#                             TrainingJobName TrainingJobStatus  \
# 0   linear-learner-210605-0830-012-c346db1e         Completed
# 5   linear-learner-210605-0830-007-9c7c3953         Completed
# 4   linear-learner-210605-0830-008-f645126b         Completed
# 8   linear-learner-210605-0830-004-89302985         Completed
# 7   linear-learner-210605-0830-005-66bb556d         Completed
# 6   linear-learner-210605-0830-006-5e669c66         Completed
# 11  linear-learner-210605-0830-001-eedde26f         Completed
# 9   linear-learner-210605-0830-003-216ff8ab         Completed
# 10  linear-learner-210605-0830-002-07821602         Completed
# 3   linear-learner-210605-0830-009-e883b035         Completed
# 2   linear-learner-210605-0830-010-bbfa34c3         Completed
# 1   linear-learner-210605-0830-011-5da6e01b         Completed
#
#         FinalObjectiveValue         TrainingStartTime  \
# 0    11993322496.0000000000 2021-06-05 08:47:01+00:00
# 5    12263449600.0000000000 2021-06-05 08:42:49+00:00
# 4    18790369280.0000000000 2021-06-05 08:42:47+00:00
# 8    20112752640.0000000000 2021-06-05 08:38:23+00:00
# 7    27814440960.0000000000 2021-06-05 08:38:13+00:00
# 6    29801060352.0000000000 2021-06-05 08:38:08+00:00
# 11  104948572160.0000000000 2021-06-05 08:33:26+00:00
# 9   278091202560.0000000000 2021-06-05 08:33:32+00:00
# 10  369924734976.0000000000 2021-06-05 08:33:37+00:00
# 3   480758988800.0000000000 2021-06-05 08:43:04+00:00
# 2  1310860771328.0000000000 2021-06-05 08:47:07+00:00
# 1  1328770318336.0000000000 2021-06-05 08:47:07+00:00
#
#              TrainingEndTime  TrainingElapsedTimeSeconds
# 0  2021-06-05 08:48:17+00:00               76.0000000000
# 5  2021-06-05 08:44:03+00:00               74.0000000000
# 4  2021-06-05 08:43:59+00:00               72.0000000000
# 8  2021-06-05 08:39:30+00:00               67.0000000000
# 7  2021-06-05 08:39:33+00:00               80.0000000000
# 6  2021-06-05 08:39:29+00:00               81.0000000000
# 11 2021-06-05 08:34:42+00:00               76.0000000000
# 9  2021-06-05 08:35:21+00:00              109.0000000000
# 10 2021-06-05 08:35:20+00:00              103.0000000000
# 3  2021-06-05 08:44:19+00:00               75.0000000000
# 2  2021-06-05 08:48:14+00:00               67.0000000000
# 1  2021-06-05 08:48:35+00:00               88.0000000000

# %%
import sagemaker

sesh = sagemaker.Session()

linear = sagemaker.estimator.Estimator(
    container,
    role,
    instance_count=1,
    instance_type="ml.m4.xlarge",
    sagemaker_session=sesh
)

linear.set_hyperparameters(
    predictor_type="regressor",
    normalize_data=True,
    optimizer="adam",
    mini_batch_size=9,
    l1=0.0000117427,
    learning_rate=0.0492325764,
    use_bias=True,
    wd=0.0000033638
)

# %%
linear.fit(inputs={"train": s3_train_data, "validation": s3_valid_data})
# Out:
# 2021-06-05 08:51:58 Starting - Starting the training job...
# 2021-06-05 08:52:22 Starting - Launching requested ML instancesProfilerReport-1622883117: InProgress
# ......
# 2021-06-05 08:53:23 Starting - Preparing the instances for training.........
# 2021-06-05 08:54:47 Downloading - Downloading input data...
# 2021-06-05 08:55:23 Training - Downloading the training image.Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [06/05/2021 08:55:35 INFO 139953232955200] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [06/05/2021 08:55:35 INFO 139953232955200] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'optimizer': 'adam', 'predictor_type': 'regressor', 'l1': '1.17427e-05', 'use_bias': 'True', 'learning_rate': '0.0492325764', 'normalize_data': 'True', 'wd': '3.3638e-06', 'mini_batch_size': '9'}
# [06/05/2021 08:55:35 INFO 139953232955200] Final configuration: {'mini_batch_size': '9', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'True', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'adam', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': '3.3638e-06', 'l1': '1.17427e-05', 'momentum': 'auto', 'learning_rate': '0.0492325764', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'True', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'regressor'}
# [06/05/2021 08:55:35 WARNING 139953232955200] Loggers have already been setup.
# Process 1 is a worker.
# [06/05/2021 08:55:35 INFO 139953232955200] Using default worker.
# [06/05/2021 08:55:35 INFO 139953232955200] Checkpoint loading and saving are disabled.
# [2021-06-05 08:55:35.958] [tensorio] [warning] TensorIO is already initialized; ignoring the initialization routine.
# [2021-06-05 08:55:35.975] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 17, "num_examples": 1, "num_bytes": 684}
# [06/05/2021 08:55:35 INFO 139953232955200] Create Store: local
# [2021-06-05 08:55:36.191] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 215, "num_examples": 24, "num_bytes": 16416}
# [06/05/2021 08:55:36 INFO 139953232955200] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f4906153dd0>
# [06/05/2021 08:55:36 INFO 139953232955200] Scaling model computed with parameters:
#  {'stdev_label':
# [734599.9]
# <NDArray 1 @cpu(0)>, 'stdev_weight':
# [ 42.392525  47.081467  29.201403  91.22553  101.91277    7.913932
#   12.495625  59.601177]
# <NDArray 8 @cpu(0)>, 'mean_label':
# [775188.94]
# <NDArray 1 @cpu(0)>, 'mean_weight':
# [24.277779  28.740744  16.513887  62.217598  76.259254   2.5925927
#   6.370371  20.65741  ]
# <NDArray 8 @cpu(0)>}
# [06/05/2021 08:55:36 INFO 139953232955200] nvidia-smi: took 0.031 seconds to run.
# [06/05/2021 08:55:36 INFO 139953232955200] nvidia-smi identified 0 GPUs.
# [06/05/2021 08:55:36 INFO 139953232955200] Number of GPUs being used: 0
# #metrics {"StartTime": 1622883336.3169482, "EndTime": 1622883336.3169925, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 225.0, "count": 1, "min": 225, "max": 225}, "Total Batches Seen": {"sum": 25.0, "count": 1, "min": 25, "max": 25}, "Max Records Seen Between Resets": {"sum": 216.0, "count": 1, "min": 216, "max": 216}, "Max Batches Seen Between Resets": {"sum": 24.0, "count": 1, "min": 24, "max": 24}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [2021-06-05 08:55:36.959] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 4, "duration": 642, "num_examples": 24, "num_bytes": 16416}
# #metrics {"StartTime": 1622883336.9596627, "EndTime": 1622883336.9597533, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_mse_objective": {"sum": 0.23623959313112278, "count": 1, "min": 0.23623959313112278, "max": 0.23623959313112278}}}
#
# #metrics {"StartTime": 1622883336.9598608, "EndTime": 1622883336.9598832, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_mse_objective": {"sum": 0.7514293193817139, "count": 1, "min": 0.7514293193817139, "max": 0.7514293193817139}}}
#
# #metrics {"StartTime": 1622883336.9599593, "EndTime": 1622883336.9599779, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_mse_objective": {"sum": 0.748180114560657, "count": 1, "min": 0.748180114560657, "max": 0.748180114560657}}}
#
# #metrics {"StartTime": 1622883336.9600384, "EndTime": 1622883336.9600565, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"train_mse_objective": {"sum": 0.6137090369507119, "count": 1, "min": 0.6137090369507119, "max": 0.6137090369507119}}}
#
# #metrics {"StartTime": 1622883336.9601152, "EndTime": 1622883336.9601336, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"train_mse_objective": {"sum": 0.5653412426235499, "count": 1, "min": 0.5653412426235499, "max": 0.5653412426235499}}}
#
# #metrics {"StartTime": 1622883336.960203, "EndTime": 1622883336.9602222, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"train_mse_objective": {"sum": 0.5398787969240436, "count": 1, "min": 0.5398787969240436, "max": 0.5398787969240436}}}
#
# #metrics {"StartTime": 1622883336.9602814, "EndTime": 1622883336.960299, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"train_mse_objective": {"sum": 0.5126565734821337, "count": 1, "min": 0.5126565734821337, "max": 0.5126565734821337}}}
#
# #metrics {"StartTime": 1622883336.9603558, "EndTime": 1622883336.9603732, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"train_mse_objective": {"sum": 0.5133925752921237, "count": 1, "min": 0.5133925752921237, "max": 0.5133925752921237}}}
#
# #metrics {"StartTime": 1622883336.9604304, "EndTime": 1622883336.9604478, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"train_mse_objective": {"sum": 0.577108410221559, "count": 1, "min": 0.577108410221559, "max": 0.577108410221559}}}
#
# #metrics {"StartTime": 1622883336.9605076, "EndTime": 1622883336.9605248, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"train_mse_objective": {"sum": 0.7670797253096545, "count": 1, "min": 0.7670797253096545, "max": 0.7670797253096545}}}
#
# #metrics {"StartTime": 1622883336.9605794, "EndTime": 1622883336.9605956, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"train_mse_objective": {"sum": 0.6889122194714017, "count": 1, "min": 0.6889122194714017, "max": 0.6889122194714017}}}
#
# #metrics {"StartTime": 1622883336.9606466, "EndTime": 1622883336.9606628, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"train_mse_objective": {"sum": 0.6377105116844177, "count": 1, "min": 0.6377105116844177, "max": 0.6377105116844177}}}
#
# #metrics {"StartTime": 1622883336.9607143, "EndTime": 1622883336.9607277, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"train_mse_objective": {"sum": 0.536419857983236, "count": 1, "min": 0.536419857983236, "max": 0.536419857983236}}}
#
# #metrics {"StartTime": 1622883336.960776, "EndTime": 1622883336.9607916, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"train_mse_objective": {"sum": 0.522895750210241, "count": 1, "min": 0.522895750210241, "max": 0.522895750210241}}}
#
# #metrics {"StartTime": 1622883336.9608433, "EndTime": 1622883336.9608603, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"train_mse_objective": {"sum": 0.48765060767807344, "count": 1, "min": 0.48765060767807344, "max": 0.48765060767807344}}}
#
# #metrics {"StartTime": 1622883336.9609082, "EndTime": 1622883336.9609241, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"train_mse_objective": {"sum": 0.5800102296526786, "count": 1, "min": 0.5800102296526786, "max": 0.5800102296526786}}}
#
# #metrics {"StartTime": 1622883336.960979, "EndTime": 1622883336.9609954, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"train_mse_objective": {"sum": 0.8083235345504902, "count": 1, "min": 0.8083235345504902, "max": 0.8083235345504902}}}
#
# #metrics {"StartTime": 1622883336.9610445, "EndTime": 1622883336.9610605, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"train_mse_objective": {"sum": 0.880928392763491, "count": 1, "min": 0.880928392763491, "max": 0.880928392763491}}}
#
# #metrics {"StartTime": 1622883336.961114, "EndTime": 1622883336.9611304, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"train_mse_objective": {"sum": 0.6606656456435168, "count": 1, "min": 0.6606656456435168, "max": 0.6606656456435168}}}
#
# #metrics {"StartTime": 1622883336.9611719, "EndTime": 1622883336.9611874, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"train_mse_objective": {"sum": 0.6862159432084473, "count": 1, "min": 0.6862159432084473, "max": 0.6862159432084473}}}
#
# #metrics {"StartTime": 1622883336.96124, "EndTime": 1622883336.9612572, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"train_mse_objective": {"sum": 0.4168610318943306, "count": 1, "min": 0.4168610318943306, "max": 0.4168610318943306}}}
#
# #metrics {"StartTime": 1622883336.961305, "EndTime": 1622883336.9613154, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"train_mse_objective": {"sum": 0.3859469206244857, "count": 1, "min": 0.3859469206244857, "max": 0.3859469206244857}}}
#
# #metrics {"StartTime": 1622883336.9613626, "EndTime": 1622883336.961379, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"train_mse_objective": {"sum": 0.40725185929073227, "count": 1, "min": 0.40725185929073227, "max": 0.40725185929073227}}}
#
# #metrics {"StartTime": 1622883336.9614325, "EndTime": 1622883336.961448, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"train_mse_objective": {"sum": 0.44933892482960663, "count": 1, "min": 0.44933892482960663, "max": 0.44933892482960663}}}
#
# #metrics {"StartTime": 1622883336.961487, "EndTime": 1622883336.9615023, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"train_mse_objective": {"sum": 0.9630429612265693, "count": 1, "min": 0.9630429612265693, "max": 0.9630429612265693}}}
#
# #metrics {"StartTime": 1622883336.9615712, "EndTime": 1622883336.9615893, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"train_mse_objective": {"sum": 0.9691422471293697, "count": 1, "min": 0.9691422471293697, "max": 0.9691422471293697}}}
#
# #metrics {"StartTime": 1622883336.9616225, "EndTime": 1622883336.9616315, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"train_mse_objective": {"sum": 0.9874725981994912, "count": 1, "min": 0.9874725981994912, "max": 0.9874725981994912}}}
#
# #metrics {"StartTime": 1622883336.9616585, "EndTime": 1622883336.9616666, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"train_mse_objective": {"sum": 0.9669387163939299, "count": 1, "min": 0.9669387163939299, "max": 0.9669387163939299}}}
#
# #metrics {"StartTime": 1622883336.961713, "EndTime": 1622883336.9617262, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"train_mse_objective": {"sum": 1.117595433085053, "count": 1, "min": 1.117595433085053, "max": 1.117595433085053}}}
#
# #metrics {"StartTime": 1622883336.9617655, "EndTime": 1622883336.9617753, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"train_mse_objective": {"sum": 1.096807196184441, "count": 1, "min": 1.096807196184441, "max": 1.096807196184441}}}
#
# #metrics {"StartTime": 1622883336.961803, "EndTime": 1622883336.9618154, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"train_mse_objective": {"sum": 1.112198249057487, "count": 1, "min": 1.112198249057487, "max": 1.112198249057487}}}
#
# #metrics {"StartTime": 1622883336.9618616, "EndTime": 1622883336.9618716, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"train_mse_objective": {"sum": 1.0939132858205725, "count": 1, "min": 1.0939132858205725, "max": 1.0939132858205725}}}
#
# [06/05/2021 08:55:36 INFO 139953232955200] #quality_metric: host=algo-1, epoch=0, train mse_objective <loss>=0.23623959313112278
# [2021-06-05 08:55:37.004] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 0, "duration": 1046, "num_examples": 1, "num_bytes": 684}
# [2021-06-05 08:55:37.092] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 2, "duration": 87, "num_examples": 6, "num_bytes": 4104}
# #metrics {"StartTime": 1622883337.1027076, "EndTime": 1622883337.1027834, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"validation_mse_objective": {"sum": 34317611463.11111, "count": 1, "min": 34317611463.11111, "max": 34317611463.11111}}}
#
# #metrics {"StartTime": 1622883337.102883, "EndTime": 1622883337.1029003, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"validation_mse_objective": {"sum": 508123822307.55554, "count": 1, "min": 508123822307.55554, "max": 508123822307.55554}}}
#
# #metrics {"StartTime": 1622883337.102968, "EndTime": 1622883337.1029873, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"validation_mse_objective": {"sum": 509864786147.55554, "count": 1, "min": 509864786147.55554, "max": 509864786147.55554}}}
#
# #metrics {"StartTime": 1622883337.1030416, "EndTime": 1622883337.1030595, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"validation_mse_objective": {"sum": 428008470148.7407, "count": 1, "min": 428008470148.7407, "max": 428008470148.7407}}}
#
# #metrics {"StartTime": 1622883337.103116, "EndTime": 1622883337.1031342, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"validation_mse_objective": {"sum": 95975682806.51852, "count": 1, "min": 95975682806.51852, "max": 95975682806.51852}}}
#
# #metrics {"StartTime": 1622883337.1031997, "EndTime": 1622883337.103217, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"validation_mse_objective": {"sum": 66667070046.81481, "count": 1, "min": 66667070046.81481, "max": 66667070046.81481}}}
#
# #metrics {"StartTime": 1622883337.1032763, "EndTime": 1622883337.1032956, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"validation_mse_objective": {"sum": 65314907932.44444, "count": 1, "min": 65314907932.44444, "max": 65314907932.44444}}}
#
# #metrics {"StartTime": 1622883337.1033645, "EndTime": 1622883337.1033823, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"validation_mse_objective": {"sum": 55151019197.62963, "count": 1, "min": 55151019197.62963, "max": 55151019197.62963}}}
#
# #metrics {"StartTime": 1622883337.1034405, "EndTime": 1622883337.1034598, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"validation_mse_objective": {"sum": 387254609995.85187, "count": 1, "min": 387254609995.85187, "max": 387254609995.85187}}}
#
# #metrics {"StartTime": 1622883337.1035151, "EndTime": 1622883337.1035337, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"validation_mse_objective": {"sum": 528152585102.2222, "count": 1, "min": 528152585102.2222, "max": 528152585102.2222}}}
#
# #metrics {"StartTime": 1622883337.1035843, "EndTime": 1622883337.1035984, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"validation_mse_objective": {"sum": 481540486181.9259, "count": 1, "min": 481540486181.9259, "max": 481540486181.9259}}}
#
# #metrics {"StartTime": 1622883337.1036458, "EndTime": 1622883337.1036592, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"validation_mse_objective": {"sum": 441245177780.14813, "count": 1, "min": 441245177780.14813, "max": 441245177780.14813}}}
#
# #metrics {"StartTime": 1622883337.103709, "EndTime": 1622883337.1037242, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"validation_mse_objective": {"sum": 70977089839.40741, "count": 1, "min": 70977089839.40741, "max": 70977089839.40741}}}
#
# #metrics {"StartTime": 1622883337.1037736, "EndTime": 1622883337.1037872, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"validation_mse_objective": {"sum": 69106060553.48148, "count": 1, "min": 69106060553.48148, "max": 69106060553.48148}}}
#
# #metrics {"StartTime": 1622883337.1038368, "EndTime": 1622883337.103853, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"validation_mse_objective": {"sum": 37724399085.03704, "count": 1, "min": 37724399085.03704, "max": 37724399085.03704}}}
#
# #metrics {"StartTime": 1622883337.103904, "EndTime": 1622883337.1039202, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"validation_mse_objective": {"sum": 108841812878.22223, "count": 1, "min": 108841812878.22223, "max": 108841812878.22223}}}
#
# #metrics {"StartTime": 1622883337.103975, "EndTime": 1622883337.103991, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"validation_mse_objective": {"sum": 578422693584.5927, "count": 1, "min": 578422693584.5927, "max": 578422693584.5927}}}
#
# #metrics {"StartTime": 1622883337.104047, "EndTime": 1622883337.1040647, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"validation_mse_objective": {"sum": 627975510546.963, "count": 1, "min": 627975510546.963, "max": 627975510546.963}}}
#
# #metrics {"StartTime": 1622883337.1041167, "EndTime": 1622883337.1041331, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"validation_mse_objective": {"sum": 481100837925.9259, "count": 1, "min": 481100837925.9259, "max": 481100837925.9259}}}
#
# #metrics {"StartTime": 1622883337.104183, "EndTime": 1622883337.1042001, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"validation_mse_objective": {"sum": 452510700885.3333, "count": 1, "min": 452510700885.3333, "max": 452510700885.3333}}}
#
# #metrics {"StartTime": 1622883337.1042492, "EndTime": 1622883337.1042657, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"validation_mse_objective": {"sum": 56688343874.37037, "count": 1, "min": 56688343874.37037, "max": 56688343874.37037}}}
#
# #metrics {"StartTime": 1622883337.1043193, "EndTime": 1622883337.1043367, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"validation_mse_objective": {"sum": 66040066275.55556, "count": 1, "min": 66040066275.55556, "max": 66040066275.55556}}}
#
# #metrics {"StartTime": 1622883337.1044047, "EndTime": 1622883337.1044228, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"validation_mse_objective": {"sum": 57608478340.74074, "count": 1, "min": 57608478340.74074, "max": 57608478340.74074}}}
#
# #metrics {"StartTime": 1622883337.1044836, "EndTime": 1622883337.1045008, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"validation_mse_objective": {"sum": 80242644005.92592, "count": 1, "min": 80242644005.92592, "max": 80242644005.92592}}}
#
# #metrics {"StartTime": 1622883337.104556, "EndTime": 1622883337.1045735, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"validation_mse_objective": {"sum": 932927327194.0741, "count": 1, "min": 932927327194.0741, "max": 932927327194.0741}}}
#
# #metrics {"StartTime": 1622883337.1046305, "EndTime": 1622883337.1046474, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"validation_mse_objective": {"sum": 958145495040.0, "count": 1, "min": 958145495040.0, "max": 958145495040.0}}}
#
# #metrics {"StartTime": 1622883337.1046896, "EndTime": 1622883337.1047063, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"validation_mse_objective": {"sum": 920907456815.4073, "count": 1, "min": 920907456815.4073, "max": 920907456815.4073}}}
#
# #metrics {"StartTime": 1622883337.1047444, "EndTime": 1622883337.1047537, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"validation_mse_objective": {"sum": 928373293662.8148, "count": 1, "min": 928373293662.8148, "max": 928373293662.8148}}}
#
# #metrics {"StartTime": 1622883337.1047802, "EndTime": 1622883337.1047885, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"validation_mse_objective": {"sum": 999050469072.5927, "count": 1, "min": 999050469072.5927, "max": 999050469072.5927}}}
#
# #metrics {"StartTime": 1622883337.1048212, "EndTime": 1622883337.1048357, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"validation_mse_objective": {"sum": 1017152128796.4445, "count": 1, "min": 1017152128796.4445, "max": 1017152128796.4445}}}
#
# #metrics {"StartTime": 1622883337.1049013, "EndTime": 1622883337.10492, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"validation_mse_objective": {"sum": 984591819662.2222, "count": 1, "min": 984591819662.2222, "max": 984591819662.2222}}}
#
# #metrics {"StartTime": 1622883337.1049888, "EndTime": 1622883337.1050076, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"validation_mse_objective": {"sum": 1017825625277.6296, "count": 1, "min": 1017825625277.6296, "max": 1017825625277.6296}}}
#
# [06/05/2021 08:55:37 INFO 139953232955200] #quality_metric: host=algo-1, epoch=0, validation mse_objective <loss>=34317611463.11111
# [06/05/2021 08:55:37 INFO 139953232955200] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=mse_objective, value=34317611463.11111
# [06/05/2021 08:55:37 INFO 139953232955200] Epoch 0: Loss improved. Updating best model
# [06/05/2021 08:55:37 INFO 139953232955200] Saving model for epoch: 0
# [06/05/2021 08:55:37 INFO 139953232955200] Saved checkpoint to "/tmp/tmpsfuwxf_n/mx-mod-0000.params"
# [06/05/2021 08:55:37 INFO 139953232955200] #progress_metric: host=algo-1, completed 6.666666666666667 % of epochs
# #metrics {"StartTime": 1622883336.3173292, "EndTime": 1622883337.1208148, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 441.0, "count": 1, "min": 441, "max": 441}, "Total Batches Seen": {"sum": 49.0, "count": 1, "min": 49, "max": 49}, "Max Records Seen Between Resets": {"sum": 216.0, "count": 1, "min": 216, "max": 216}, "Max Batches Seen Between Resets": {"sum": 24.0, "count": 1, "min": 24, "max": 24}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 216.0, "count": 1, "min": 216, "max": 216}, "Number of Batches Since Last Reset": {"sum": 24.0, "count": 1, "min": 24, "max": 24}}}
#
# [06/05/2021 08:55:37 INFO 139953232955200] #throughput_metric: host=algo-1, train throughput=268.77502836175836 records/second
# [2021-06-05 08:55:37.951] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 6, "duration": 830, "num_examples": 24, "num_bytes": 16416}
# #metrics {"StartTime": 1622883337.952011, "EndTime": 1622883337.9521096, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_mse_objective": {"sum": 0.049614843946916086, "count": 1, "min": 0.049614843946916086, "max": 0.049614843946916086}}}
#
# #metrics {"StartTime": 1622883337.952187, "EndTime": 1622883337.9522712, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"train_mse_objective": {"sum": 0.34075677174109, "count": 1, "min": 0.34075677174109, "max": 0.34075677174109}}}
#
# #metrics {"StartTime": 1622883337.9523888, "EndTime": 1622883337.952413, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"train_mse_objective": {"sum": 0.3544051553364153, "count": 1, "min": 0.3544051553364153, "max": 0.3544051553364153}}}
#
# #metrics {"StartTime": 1622883337.9524677, "EndTime": 1622883337.95248, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_mse_objective": {"sum": 0.2758962396118376, "count": 1, "min": 0.2758962396118376, "max": 0.2758962396118376}}}
#
# #metrics {"StartTime": 1622883337.9525402, "EndTime": 1622883337.9525576, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"train_mse_objective": {"sum": 0.08551870424438406, "count": 1, "min": 0.08551870424438406, "max": 0.08551870424438406}}}
#
# #metrics {"StartTime": 1622883337.9526122, "EndTime": 1622883337.9526336, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"train_mse_objective": {"sum": 0.09731595442388896, "count": 1, "min": 0.09731595442388896, "max": 0.09731595442388896}}}
#
# #metrics {"StartTime": 1622883337.9526882, "EndTime": 1622883337.952701, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"train_mse_objective": {"sum": 0.08315129833364929, "count": 1, "min": 0.08315129833364929, "max": 0.08315129833364929}}}
#
# #metrics {"StartTime": 1622883337.95276, "EndTime": 1622883337.9527774, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"train_mse_objective": {"sum": 0.0898465715624668, "count": 1, "min": 0.0898465715624668, "max": 0.0898465715624668}}}
#
# #metrics {"StartTime": 1622883337.9528306, "EndTime": 1622883337.9528463, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"train_mse_objective": {"sum": 0.25144288688898087, "count": 1, "min": 0.25144288688898087, "max": 0.25144288688898087}}}
#
# #metrics {"StartTime": 1622883337.9528992, "EndTime": 1622883337.9529161, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"train_mse_objective": {"sum": 0.356106704307927, "count": 1, "min": 0.356106704307927, "max": 0.356106704307927}}}
#
# #metrics {"StartTime": 1622883337.9529722, "EndTime": 1622883337.952987, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"train_mse_objective": {"sum": 0.33021462791495854, "count": 1, "min": 0.33021462791495854, "max": 0.33021462791495854}}}
#
# #metrics {"StartTime": 1622883337.9530416, "EndTime": 1622883337.9530597, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"train_mse_objective": {"sum": 0.2879968117232676, "count": 1, "min": 0.2879968117232676, "max": 0.2879968117232676}}}
#
# #metrics {"StartTime": 1622883337.9531128, "EndTime": 1622883337.9531276, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"train_mse_objective": {"sum": 0.08508646529581812, "count": 1, "min": 0.08508646529581812, "max": 0.08508646529581812}}}
#
# #metrics {"StartTime": 1622883337.953182, "EndTime": 1622883337.953195, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"train_mse_objective": {"sum": 0.09361955606275135, "count": 1, "min": 0.09361955606275135, "max": 0.09361955606275135}}}
#
# #metrics {"StartTime": 1622883337.9532487, "EndTime": 1622883337.9532676, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"train_mse_objective": {"sum": 0.09119513893017063, "count": 1, "min": 0.09119513893017063, "max": 0.09119513893017063}}}
#
# #metrics {"StartTime": 1622883337.9533193, "EndTime": 1622883337.9533381, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"train_mse_objective": {"sum": 0.08613646223589226, "count": 1, "min": 0.08613646223589226, "max": 0.08613646223589226}}}
#
# #metrics {"StartTime": 1622883337.9533904, "EndTime": 1622883337.9534066, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"train_mse_objective": {"sum": 0.42203638288709855, "count": 1, "min": 0.42203638288709855, "max": 0.42203638288709855}}}
#
# #metrics {"StartTime": 1622883337.9534552, "EndTime": 1622883337.9534721, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"train_mse_objective": {"sum": 0.45762379191539904, "count": 1, "min": 0.45762379191539904, "max": 0.45762379191539904}}}
#
# #metrics {"StartTime": 1622883337.953526, "EndTime": 1622883337.9535391, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"train_mse_objective": {"sum": 0.34554322339870314, "count": 1, "min": 0.34554322339870314, "max": 0.34554322339870314}}}
#
# #metrics {"StartTime": 1622883337.9535942, "EndTime": 1622883337.953613, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"train_mse_objective": {"sum": 0.3343448558891261, "count": 1, "min": 0.3343448558891261, "max": 0.3343448558891261}}}
#
# #metrics {"StartTime": 1622883337.9536655, "EndTime": 1622883337.9536798, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"train_mse_objective": {"sum": 0.19820040174656445, "count": 1, "min": 0.19820040174656445, "max": 0.19820040174656445}}}
#
# #metrics {"StartTime": 1622883337.953735, "EndTime": 1622883337.9537516, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"train_mse_objective": {"sum": 0.18471458423192855, "count": 1, "min": 0.18471458423192855, "max": 0.18471458423192855}}}
#
# #metrics {"StartTime": 1622883337.9538004, "EndTime": 1622883337.9538188, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"train_mse_objective": {"sum": 0.19511613822369664, "count": 1, "min": 0.19511613822369664, "max": 0.19511613822369664}}}
#
# #metrics {"StartTime": 1622883337.95387, "EndTime": 1622883337.95389, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"train_mse_objective": {"sum": 0.19614199921488762, "count": 1, "min": 0.19614199921488762, "max": 0.19614199921488762}}}
#
# #metrics {"StartTime": 1622883337.953925, "EndTime": 1622883337.9539397, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"train_mse_objective": {"sum": 0.9686915046638913, "count": 1, "min": 0.9686915046638913, "max": 0.9686915046638913}}}
#
# #metrics {"StartTime": 1622883337.953988, "EndTime": 1622883337.9540043, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"train_mse_objective": {"sum": 0.9608050308845661, "count": 1, "min": 0.9608050308845661, "max": 0.9608050308845661}}}
#
# #metrics {"StartTime": 1622883337.9540548, "EndTime": 1622883337.9541054, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"train_mse_objective": {"sum": 0.9603334179630986, "count": 1, "min": 0.9603334179630986, "max": 0.9603334179630986}}}
#
# #metrics {"StartTime": 1622883337.954167, "EndTime": 1622883337.954182, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"train_mse_objective": {"sum": 0.9739166332615746, "count": 1, "min": 0.9739166332615746, "max": 0.9739166332615746}}}
#
# #metrics {"StartTime": 1622883337.9542382, "EndTime": 1622883337.954253, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"train_mse_objective": {"sum": 1.100687039119226, "count": 1, "min": 1.100687039119226, "max": 1.100687039119226}}}
#
# #metrics {"StartTime": 1622883337.9543073, "EndTime": 1622883337.954322, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"train_mse_objective": {"sum": 1.0978502962324355, "count": 1, "min": 1.0978502962324355, "max": 1.0978502962324355}}}
#
# #metrics {"StartTime": 1622883337.9543755, "EndTime": 1622883337.9543915, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 30}, "Metrics": {"train_mse_objective": {"sum": 1.1081736396860193, "count": 1, "min": 1.1081736396860193, "max": 1.1081736396860193}}}
#
# #metrics {"StartTime": 1622883337.9544485, "EndTime": 1622883337.9544656, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 31}, "Metrics": {"train_mse_objective": {"sum": 1.1192805524225589, "count": 1, "min": 1.1192805524225589, "max": 1.1192805524225589}}}
#
# [06/05/2021 08:55:37 INFO 139953232955200] #quality_metric: host=algo-1, epoch=1, train mse_objective <loss>=0.049614843946916086
# [2021-06-05 08:55:38.095] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 5, "duration": 99, "num_examples": 6, "num_bytes": 4104}
# #metrics {"StartTime": 1622883338.1059318, "EndTime": 1622883338.106015, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"validation_mse_objective": {"sum": 20392240165.925926, "count": 1, "min": 20392240165.925926, "max": 20392240165.925926}}}
#
# #metrics {"StartTime": 1622883338.1061428, "EndTime": 1622883338.1061668, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"validation_mse_objective": {"sum": 233527764461.03705, "count": 1, "min": 233527764461.03705, "max": 233527764461.03705}}}
#
# #metrics {"StartTime": 1622883338.106239, "EndTime": 1622883338.106257, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"validation_mse_objective": {"sum": 245830030677.33334, "count": 1, "min": 245830030677.33334, "max": 245830030677.33334}}}
#
# #metrics {"StartTime": 1622883338.106324, "EndTime": 1622883338.1063418, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"validation_mse_objective": {"sum": 194541614724.74075, "count": 1, "min": 194541614724.74075, "max": 194541614724.74075}}}
#
# #metrics {"StartTime": 1622883338.1063962, "EndTime": 1622883338.10641, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"validation_mse_objective": {"sum": 38320569457.77778, "count": 1, "min": 38320569457.77778, "max": 38320569457.77778}}}
#
# #metrics {"StartTime": 1622883338.1064632, "EndTime": 1622883338.1064823, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"validation_mse_objective": {"sum": 27562424395.851852, "count": 1, "min": 27562424395.851852, "max": 27562424395.851852}}}
#
# #metrics {"StartTime": 1622883338.1065466, "EndTime": 1622883338.1065633, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"validation_mse_objective": {"sum": 22916305882.074074, "count": 1, "min": 22916305882.074074, "max": 22916305882.074074}}}
#
# #metrics {"StartTime": 1622883338.1066163, "EndTime": 1622883338.106636, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"validation_mse_objective": {"sum": 15980728168.296297, "count": 1, "min": 15980728168.296297, "max": 15980728168.296297}}}
#
# #metrics {"StartTime": 1622883338.1066988, "EndTime": 1622883338.106715, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"validation_mse_objective": {"sum": 172313131842.37036, "count": 1, "min": 172313131842.37036, "max": 172313131842.37036}}}
#
# #metrics {"StartTime": 1622883338.1067634, "EndTime": 1622883338.1067784, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"validation_mse_objective": {"sum": 246701672827.25925, "count": 1, "min": 246701672827.25925, "max": 246701672827.25925}}}
#
# #metrics {"StartTime": 1622883338.106837, "EndTime": 1622883338.1068563, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"validation_mse_objective": {"sum": 232454142482.96295, "count": 1, "min": 232454142482.96295, "max": 232454142482.96295}}}
#
# #metrics {"StartTime": 1622883338.1069021, "EndTime": 1622883338.1069167, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"validation_mse_objective": {"sum": 199423270001.77777, "count": 1, "min": 199423270001.77777, "max": 199423270001.77777}}}
#
# #metrics {"StartTime": 1622883338.10697, "EndTime": 1622883338.1069841, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"validation_mse_objective": {"sum": 36394020864.0, "count": 1, "min": 36394020864.0, "max": 36394020864.0}}}
#
# #metrics {"StartTime": 1622883338.1070244, "EndTime": 1622883338.1070414, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"validation_mse_objective": {"sum": 23714442960.592594, "count": 1, "min": 23714442960.592594, "max": 23714442960.592594}}}
#
# #metrics {"StartTime": 1622883338.107093, "EndTime": 1622883338.1071124, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"validation_mse_objective": {"sum": 13996514645.333334, "count": 1, "min": 13996514645.333334, "max": 13996514645.333334}}}
#
# #metrics {"StartTime": 1622883338.1071522, "EndTime": 1622883338.1071713, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"validation_mse_objective": {"sum": 39713394536.296295, "count": 1, "min": 39713394536.296295, "max": 39713394536.296295}}}
#
# #metrics {"StartTime": 1622883338.1072187, "EndTime": 1622883338.1072345, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"validation_mse_objective": {"sum": 322054430416.5926, "count": 1, "min": 322054430416.5926, "max": 322054430416.5926}}}
#
# #metrics {"StartTime": 1622883338.1072881, "EndTime": 1622883338.107304, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"validation_mse_objective": {"sum": 343808024272.5926, "count": 1, "min": 343808024272.5926, "max": 343808024272.5926}}}
#
# #metrics {"StartTime": 1622883338.1073573, "EndTime": 1622883338.1073725, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"validation_mse_objective": {"sum": 269431280981.33334, "count": 1, "min": 269431280981.33334, "max": 269431280981.33334}}}
#
# #metrics {"StartTime": 1622883338.1074216, "EndTime": 1622883338.1074386, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"validation_mse_objective": {"sum": 241405936829.62964, "count": 1, "min": 241405936829.62964, "max": 241405936829.62964}}}
#
# #metrics {"StartTime": 1622883338.1074917, "EndTime": 1622883338.1075077, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"validation_mse_objective": {"sum": 122480948261.92592, "count": 1, "min": 122480948261.92592, "max": 122480948261.92592}}}
#
# #metrics {"StartTime": 1622883338.107574, "EndTime": 1622883338.107587, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"validation_mse_objective": {"sum": 152720210754.37036, "count": 1, "min": 152720210754.37036, "max": 152720210754.37036}}}
#
# #metrics {"StartTime": 1622883338.1076431, "EndTime": 1622883338.1076596, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"validation_mse_objective": {"sum": 129684832256.0, "count": 1, "min": 129684832256.0, "max": 129684832256.0}}}
#
# #metrics {"StartTime": 1622883338.1077101, "EndTime": 1622883338.1077266, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"validation_mse_objective": {"sum": 125280521784.88889, "count": 1, "min": 125280521784.88889, "max": 125280521784.88889}}}
#
# #metrics {"StartTime": 1622883338.1077828, "EndTime": 1622883338.1077983, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"validation_mse_objective": {"sum": 930679903573.3334, "count": 1, "min": 930679903573.3334, "max": 930679903573.3334}}}
#
# #metrics {"StartTime": 1622883338.1078484, "EndTime": 1622883338.1078663, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"validation_mse_objective": {"sum": 939514435508.1482, "count": 1, "min": 939514435508.1482, "max": 939514435508.1482}}}
#
# ...
#
# #metrics {"StartTime": 1622883347.9275079, "EndTime": 1622883347.9275231, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 29}, "Metrics": {"train_mse_objective": {"sum": 1.1306417518191867, "count": 1, "min": 1.1306417518191867, "max": 1.1306417518191867}}}
#
# #metrics {"StartTime": 1622883347.9276006, "EndTime": 1622883347.9276168, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 30}, "Metrics": {"train_mse_objective": {"sum": 1.0428697047410187, "count": 1, "min": 1.0428697047410187, "max": 1.0428697047410187}}}
#
# #metrics {"StartTime": 1622883347.9276726, "EndTime": 1622883347.927687, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 31}, "Metrics": {"train_mse_objective": {"sum": 1.1334028795913413, "count": 1, "min": 1.1334028795913413, "max": 1.1334028795913413}}}
#
# [06/05/2021 08:55:47 INFO 139953232955200] #quality_metric: host=algo-1, epoch=14, train mse_objective <loss>=0.030842325012027112
# [2021-06-05 08:55:48.036] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 44, "duration": 77, "num_examples": 6, "num_bytes": 4104}
# #metrics {"StartTime": 1622883348.044432, "EndTime": 1622883348.0444963, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 0}, "Metrics": {"validation_mse_objective": {"sum": 11993318741.333334, "count": 1, "min": 11993318741.333334, "max": 11993318741.333334}}}
#
# #metrics {"StartTime": 1622883348.0445857, "EndTime": 1622883348.0446076, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 1}, "Metrics": {"validation_mse_objective": {"sum": 7071306240.0, "count": 1, "min": 7071306240.0, "max": 7071306240.0}}}
#
# #metrics {"StartTime": 1622883348.044691, "EndTime": 1622883348.0447083, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 2}, "Metrics": {"validation_mse_objective": {"sum": 6937693980.444445, "count": 1, "min": 6937693980.444445, "max": 6937693980.444445}}}
#
# #metrics {"StartTime": 1622883348.0447564, "EndTime": 1622883348.0447695, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 3}, "Metrics": {"validation_mse_objective": {"sum": 6854665576.296296, "count": 1, "min": 6854665576.296296, "max": 6854665576.296296}}}
#
# #metrics {"StartTime": 1622883348.0448284, "EndTime": 1622883348.0448458, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 4}, "Metrics": {"validation_mse_objective": {"sum": 22800923496.296295, "count": 1, "min": 22800923496.296295, "max": 22800923496.296295}}}
#
# #metrics {"StartTime": 1622883348.0448954, "EndTime": 1622883348.0449123, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 5}, "Metrics": {"validation_mse_objective": {"sum": 90813760094.81482, "count": 1, "min": 90813760094.81482, "max": 90813760094.81482}}}
#
# #metrics {"StartTime": 1622883348.0449672, "EndTime": 1622883348.0449853, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 6}, "Metrics": {"validation_mse_objective": {"sum": 30399677629.62963, "count": 1, "min": 30399677629.62963, "max": 30399677629.62963}}}
#
# #metrics {"StartTime": 1622883348.0450532, "EndTime": 1622883348.0450716, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 7}, "Metrics": {"validation_mse_objective": {"sum": 92198742698.66667, "count": 1, "min": 92198742698.66667, "max": 92198742698.66667}}}
#
# #metrics {"StartTime": 1622883348.0451248, "EndTime": 1622883348.0451436, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 8}, "Metrics": {"validation_mse_objective": {"sum": 7594603463.111111, "count": 1, "min": 7594603463.111111, "max": 7594603463.111111}}}
#
# #metrics {"StartTime": 1622883348.045206, "EndTime": 1622883348.0452237, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 9}, "Metrics": {"validation_mse_objective": {"sum": 7187122157.037037, "count": 1, "min": 7187122157.037037, "max": 7187122157.037037}}}
#
# #metrics {"StartTime": 1622883348.0452776, "EndTime": 1622883348.0452917, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 10}, "Metrics": {"validation_mse_objective": {"sum": 7513420060.444445, "count": 1, "min": 7513420060.444445, "max": 7513420060.444445}}}
#
# #metrics {"StartTime": 1622883348.0453563, "EndTime": 1622883348.0453734, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 11}, "Metrics": {"validation_mse_objective": {"sum": 7317597809.777778, "count": 1, "min": 7317597809.777778, "max": 7317597809.777778}}}
#
# #metrics {"StartTime": 1622883348.045418, "EndTime": 1622883348.0454326, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 12}, "Metrics": {"validation_mse_objective": {"sum": 31592039310.22222, "count": 1, "min": 31592039310.22222, "max": 31592039310.22222}}}
#
# #metrics {"StartTime": 1622883348.0454855, "EndTime": 1622883348.045501, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 13}, "Metrics": {"validation_mse_objective": {"sum": 85165983364.74074, "count": 1, "min": 85165983364.74074, "max": 85165983364.74074}}}
#
# #metrics {"StartTime": 1622883348.045549, "EndTime": 1622883348.0455637, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 14}, "Metrics": {"validation_mse_objective": {"sum": 40850738972.44444, "count": 1, "min": 40850738972.44444, "max": 40850738972.44444}}}
#
# #metrics {"StartTime": 1622883348.0456104, "EndTime": 1622883348.045626, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 15}, "Metrics": {"validation_mse_objective": {"sum": 86083197610.66667, "count": 1, "min": 86083197610.66667, "max": 86083197610.66667}}}
#
# #metrics {"StartTime": 1622883348.0456765, "EndTime": 1622883348.045696, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 16}, "Metrics": {"validation_mse_objective": {"sum": 119514012482.37038, "count": 1, "min": 119514012482.37038, "max": 119514012482.37038}}}
#
# #metrics {"StartTime": 1622883348.0457504, "EndTime": 1622883348.0457668, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 17}, "Metrics": {"validation_mse_objective": {"sum": 118676463464.2963, "count": 1, "min": 118676463464.2963, "max": 118676463464.2963}}}
#
# #metrics {"StartTime": 1622883348.0458136, "EndTime": 1622883348.0458295, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 18}, "Metrics": {"validation_mse_objective": {"sum": 119371026583.7037, "count": 1, "min": 119371026583.7037, "max": 119371026583.7037}}}
#
# #metrics {"StartTime": 1622883348.0458815, "EndTime": 1622883348.0458984, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 19}, "Metrics": {"validation_mse_objective": {"sum": 118295087483.25926, "count": 1, "min": 118295087483.25926, "max": 118295087483.25926}}}
#
# #metrics {"StartTime": 1622883348.045945, "EndTime": 1622883348.0459623, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 20}, "Metrics": {"validation_mse_objective": {"sum": 113854979792.59259, "count": 1, "min": 113854979792.59259, "max": 113854979792.59259}}}
#
# #metrics {"StartTime": 1622883348.046014, "EndTime": 1622883348.0460317, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 21}, "Metrics": {"validation_mse_objective": {"sum": 100036075216.59259, "count": 1, "min": 100036075216.59259, "max": 100036075216.59259}}}
#
# #metrics {"StartTime": 1622883348.0461123, "EndTime": 1622883348.0461264, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 22}, "Metrics": {"validation_mse_objective": {"sum": 113820543658.66667, "count": 1, "min": 113820543658.66667, "max": 113820543658.66667}}}
#
# #metrics {"StartTime": 1622883348.046185, "EndTime": 1622883348.0461993, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 23}, "Metrics": {"validation_mse_objective": {"sum": 100098215480.88889, "count": 1, "min": 100098215480.88889, "max": 100098215480.88889}}}
#
# #metrics {"StartTime": 1622883348.0462523, "EndTime": 1622883348.0462666, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 24}, "Metrics": {"validation_mse_objective": {"sum": 936764600775.1111, "count": 1, "min": 936764600775.1111, "max": 936764600775.1111}}}
#
# #metrics {"StartTime": 1622883348.0463223, "EndTime": 1622883348.046339, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 25}, "Metrics": {"validation_mse_objective": {"sum": 933837391644.4445, "count": 1, "min": 933837391644.4445, "max": 933837391644.4445}}}
#
# #metrics {"StartTime": 1622883348.046402, "EndTime": 1622883348.0464149, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 26}, "Metrics": {"validation_mse_objective": {"sum": 936606785232.5927, "count": 1, "min": 936606785232.5927, "max": 936606785232.5927}}}
#
# #metrics {"StartTime": 1622883348.0464814, "EndTime": 1622883348.0464935, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 27}, "Metrics": {"validation_mse_objective": {"sum": 929567968824.8889, "count": 1, "min": 929567968824.8889, "max": 929567968824.8889}}}
#
# #metrics {"StartTime": 1622883348.0465589, "EndTime": 1622883348.0465767, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 28}, "Metrics": {"validation_mse_objective": {"sum": 984972690621.6296, "count": 1, "min": 984972690621.6296, "max": 984972690621.6296}}}
#
# #metrics {"StartTime": 1622883348.046627, "EndTime": 1622883348.046643, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 29}, "Metrics": {"validation_mse_objective": {"sum": 1100444234183.111, "count": 1, "min": 1100444234183.111, "max": 1100444234183.111}}}
#
# #metrics {"StartTime": 1622883348.0467062, "EndTime": 1622883348.0467257, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 30}, "Metrics": {"validation_mse_objective": {"sum": 983759182354.963, "count": 1, "min": 983759182354.963, "max": 983759182354.963}}}
#
# #metrics {"StartTime": 1622883348.0467796, "EndTime": 1622883348.0468006, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 31}, "Metrics": {"validation_mse_objective": {"sum": 1090109333200.5927, "count": 1, "min": 1090109333200.5927, "max": 1090109333200.5927}}}
#
# [06/05/2021 08:55:48 INFO 139953232955200] #quality_metric: host=algo-1, epoch=14, validation mse_objective <loss>=11993318741.333334
# [06/05/2021 08:55:48 INFO 139953232955200] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=mse_objective, value=6854665576.296296
# [06/05/2021 08:55:48 INFO 139953232955200] Epoch 14: Loss improved. Updating best model
# [06/05/2021 08:55:48 INFO 139953232955200] Saving model for epoch: 14
# [06/05/2021 08:55:48 INFO 139953232955200] Saved checkpoint to "/tmp/tmpdu6h3egh/mx-mod-0000.params"
# [06/05/2021 08:55:48 INFO 139953232955200] #progress_metric: host=algo-1, completed 100.0 % of epochs
# #metrics {"StartTime": 1622883347.282463, "EndTime": 1622883348.0540948, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 3465.0, "count": 1, "min": 3465, "max": 3465}, "Total Batches Seen": {"sum": 385.0, "count": 1, "min": 385, "max": 385}, "Max Records Seen Between Resets": {"sum": 216.0, "count": 1, "min": 216, "max": 216}, "Max Batches Seen Between Resets": {"sum": 24.0, "count": 1, "min": 24, "max": 24}, "Reset Count": {"sum": 17.0, "count": 1, "min": 17, "max": 17}, "Number of Records Since Last Reset": {"sum": 216.0, "count": 1, "min": 216, "max": 216}, "Number of Batches Since Last Reset": {"sum": 24.0, "count": 1, "min": 24, "max": 24}}}
#
# [06/05/2021 08:55:48 INFO 139953232955200] #throughput_metric: host=algo-1, train throughput=279.878463187181 records/second
# [06/05/2021 08:55:48 WARNING 139953232955200] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [06/05/2021 08:55:48 WARNING 139953232955200] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2021-06-05 08:55:48.148] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 47, "duration": 70, "num_examples": 6, "num_bytes": 4104}
# [06/05/2021 08:55:48 INFO 139953232955200] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=mse_objective, value=6854665576.296296
# [2021-06-05 08:55:48.169] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 49, "duration": 9, "num_examples": 6, "num_bytes": 4104}
# [06/05/2021 08:55:48 INFO 139953232955200] #validation_score (algo-1) : ('mse_objective', 6854665576.296296)
# [06/05/2021 08:55:48 INFO 139953232955200] #validation_score (algo-1) : ('mse', 6854665576.296296)
# [06/05/2021 08:55:48 INFO 139953232955200] #validation_score (algo-1) : ('absolute_loss', 45813.90248842593)
# [06/05/2021 08:55:48 INFO 139953232955200] #quality_metric: host=algo-1, validation mse_objective <loss>=6854665576.296296
# [06/05/2021 08:55:48 INFO 139953232955200] #quality_metric: host=algo-1, validation mse <loss>=6854665576.296296
# [06/05/2021 08:55:48 INFO 139953232955200] #quality_metric: host=algo-1, validation absolute_loss <loss>=45813.90248842593
# [06/05/2021 08:55:48 INFO 139953232955200] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.005, "wd": 0.0001, "l1": 0.0, "lr_scheduler_step": 100, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 0.0001}
# [06/05/2021 08:55:48 INFO 139953232955200] Saved checkpoint to "/tmp/tmp7njqtkjj/mx-mod-0000.params"
# [06/05/2021 08:55:48 INFO 139953232955200] Test data is not provided.
# #metrics {"StartTime": 1622883335.9569583, "EndTime": 1622883348.1766407, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 358.1280708312988, "count": 1, "min": 358.1280708312988, "max": 358.1280708312988}, "epochs": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "check_early_stopping.time": {"sum": 16.64900779724121, "count": 16, "min": 0.2605915069580078, "max": 1.474142074584961}, "update.time": {"sum": 11676.183462142944, "count": 15, "min": 658.5564613342285, "max": 992.7265644073486}, "finalize.time": {"sum": 116.23668670654297, "count": 1, "min": 116.23668670654297, "max": 116.23668670654297}, "setuptime": {"sum": 33.3249568939209, "count": 1, "min": 33.3249568939209, "max": 33.3249568939209}, "totaltime": {"sum": 12520.970582962036, "count": 1, "min": 12520.970582962036, "max": 12520.970582962036}}}
#
# Training seconds: 73
# Billable seconds: 73

# %%
linear_predictor = linear.deploy(initial_instance_count=1, instance_type="ml.t2.medium")
print(f"\ncreated endpoint: {linear_predictor.endpoint_name}")
# Out:
# ---------------------!
# created endpoint: linear-learner-2021-06-05-08-56-11-696

# %%
from sagemaker.serializers import CSVSerializer

linear_predictor.serializer = CSVSerializer()
payload = df.drop(['target'], axis=1)
result = linear_predictor.predict(payload.values)

# %%
import json

res = json.loads(result.decode())
res['predictions'][0]
# Out:
# {'score': 148868.5625}

# %%
y_pred_len = len(res['predictions'])
y_pred_len
# Out:
# 270

# %%
y_pred_len = len(res['predictions'])
y_pred_scores = []

for i in range(y_pred_len):
    y_pred_scores.append(res['predictions'][i].get('score'))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  270 non-null    int64
#  1   a       270 non-null    int64
#  2   b       270 non-null    int64
#  3   c       270 non-null    int64
#  4   d       270 non-null    int64
#  5   e       270 non-null    int64
#  6   f       270 non-null    int64
#  7   g       270 non-null    int64
#  8   h       270 non-null    int64
# dtypes: int64(9)
# memory usage: 19.1 KB

# %%
# init output DF
output_df = pd.DataFrame()

# populate DF
output_df['Actual'] = df['target'].values
output_df['Predicted'] = y_pred_scores

output_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Actual     270 non-null    int64
#  1   Predicted  270 non-null    float64
# dtypes: float64(1), int64(1)
# memory usage: 4.3 KB

# %%
import seaborn as sns
import matplotlib.pylab as plt

plt.style.use('fivethirtyeight')
plt.figure(figsize=(10,8))

sns.regplot(output_df['Actual'], output_df['Predicted'], line_kws={'color': 'gold'})

plt.xlabel("actual values")
plt.ylabel("predicted values")
plt.title("\nHyperparameter-tuned Linear Learner Model\nActual vs. Predicted values\n")
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, '\nHyperparameter-tuned Linear Learner Model\nActual vs. Predicted values\n')

# %%
from sklearn.metrics import mean_squared_error as MSE
from sklearn.metrics import r2_score

# helper function for evaluating a model
def evaluate(labels, predictions):
    # get rmse values and r^2 scores 
    rmse = np.sqrt(MSE(labels, predictions))
    
    r2 = r2_score(labels, predictions)
    
    return rmse, r2

# get rmse values and r^2 scores using the helper function
lr_rmse, lr_r2 = evaluate(output_df['Actual'], output_df['Predicted'])

print(f'\nRMSE = {lr_rmse}')
print(f'R^2 Score = {lr_r2 * 100}\n')
# Out:
# RMSE = 88923.13144556922
# R^2 Score = 98.74362274799591

# %%
linear_predictor.delete_endpoint()
print(f"deleted {linear_predictor.endpoint_name} successfully!")
# Out:
# deleted linear-learner-2021-06-05-08-56-11-696 successfully!
